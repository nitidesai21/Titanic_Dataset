# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

# %%
data=pd.read_csv(r"C:\Users\desai\OneDrive\Desktop\niti\Internship_Project\tested.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
age_mean=data["Age"].mean()

# %%
data["Age"]=data["Age"].fillna(value=age_mean)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# 413                            Spector, Mr. Woolf    male  30.27259      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.00000      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.50000      0
# 416                           Ware, Mr. Frederick    male  30.27259      0
# 417                      Peter, Master. Michael J    male  30.27259      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0              330911    7.8292   NaN        Q
# 1        0              363272    7.0000   NaN        S
# 2        0              240276    9.6875   NaN        Q
# 3        0              315154    8.6625   NaN        S
# 4        1             3101298   12.2875   NaN        S
# ..     ...                 ...       ...   ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data["Fare"]=data["Fare"].fillna(value=data["Fare"].mean())

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
label_encoding=LabelEncoder()

# %%
data["Embarked_encoded"]=label_encoding.fit_transform(data["Embarked"])

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# 413                            Spector, Mr. Woolf    male  30.27259      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.00000      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.50000      0
# 416                           Ware, Mr. Frederick    male  30.27259      0
# 417                      Peter, Master. Michael J    male  30.27259      1
#
#      Parch              Ticket      Fare Cabin Embarked  Embarked_encoded
# 0        0              330911    7.8292   NaN        Q                 1
# 1        0              363272    7.0000   NaN        S                 2
# 2        0              240276    9.6875   NaN        Q                 1
# 3        0              315154    8.6625   NaN        S                 2
# 4        1             3101298   12.2875   NaN        S                 2
# ..     ...                 ...       ...   ...      ...               ...
# 413      0           A.5. 3236    8.0500   NaN        S                 2
# 414      0            PC 17758  108.9000  C105        C                 0
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S                 2
# 416      0              359309    8.0500   NaN        S                 2
# 417      1                2668   22.3583   NaN        C                 0
#
# [418 rows x 13 columns]

# %%
data["Embarked_encoded"]=data["Embarked_encoded"].fillna(0)

# %%
data.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               327
# Embarked              0
# Embarked_encoded      0
# dtype: int64

# %%
data["Cabin_Encoded"]=label_encoding.fit_transform(data["Cabin"])

# %%
data["Cabin_Encoded"]=data["Cabin_Encoded"].fillna(0)

# %%
data.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               327
# Embarked              0
# Embarked_encoded      0
# Cabin_Encoded         0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# 413                            Spector, Mr. Woolf    male  30.27259      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.00000      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.50000      0
# 416                           Ware, Mr. Frederick    male  30.27259      0
# 417                      Peter, Master. Michael J    male  30.27259      1
#
#      Parch              Ticket      Fare Cabin Embarked  Embarked_encoded  \
# 0        0              330911    7.8292   NaN        Q                 1
# 1        0              363272    7.0000   NaN        S                 2
# 2        0              240276    9.6875   NaN        Q                 1
# 3        0              315154    8.6625   NaN        S                 2
# 4        1             3101298   12.2875   NaN        S                 2
# ..     ...                 ...       ...   ...      ...               ...
# 413      0           A.5. 3236    8.0500   NaN        S                 2
# 414      0            PC 17758  108.9000  C105        C                 0
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S                 2
# 416      0              359309    8.0500   NaN        S                 2
# 417      1                2668   22.3583   NaN        C                 0
#
#      Cabin_Encoded
# 0               76
# 1               76
# 2               76
# 3               76
# 4               76
# ..             ...
# 413             76
# 414             22
# 415             76
# 416             76
# 417             76
#
# [418 rows x 14 columns]

# %%
sns.catplot(data=data,kind="bar",x="Pclass",y="Fare",hue="Sex")
plt.show()

# %%
sns.countplot(x="Sex",data=data)
plt.show()

# %%
sns.countplot(x="Pclass",data=data)
plt.show()

# %%
data["Fare"].value_counts().shape
# Out:
# (170,)

# %%
sns.boxplot(x="Embarked",y="Age",hue="Survived",data=data)
plt.show()

# %%
sns.displot(data,x="Age",col="Survived",binwidth=3,height=3,facet_kws=dict(margin_titles=True))
plt.show()
# Out:
# C:\Users\desai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\desai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\desai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\desai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
encoded_gender=label_encoding.fit_transform(data["Sex"])

# %%
data["Sex_encoded"]=encoded_gender

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# 413                            Spector, Mr. Woolf    male  30.27259      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.00000      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.50000      0
# 416                           Ware, Mr. Frederick    male  30.27259      0
# 417                      Peter, Master. Michael J    male  30.27259      1
#
#      Parch              Ticket      Fare Cabin Embarked  Embarked_encoded  \
# 0        0              330911    7.8292   NaN        Q                 1
# 1        0              363272    7.0000   NaN        S                 2
# 2        0              240276    9.6875   NaN        Q                 1
# 3        0              315154    8.6625   NaN        S                 2
# 4        1             3101298   12.2875   NaN        S                 2
# ..     ...                 ...       ...   ...      ...               ...
# 413      0           A.5. 3236    8.0500   NaN        S                 2
# 414      0            PC 17758  108.9000  C105        C                 0
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S                 2
# 416      0              359309    8.0500   NaN        S                 2
# 417      1                2668   22.3583   NaN        C                 0
#
#      Cabin_Encoded  Sex_encoded
# 0               76            1
# 1               76            0
# 2               76            1
# 3               76            1
# 4               76            0
# ..             ...          ...
# 413             76            1
# 414             22            0
# 415             76            1
# 416             76            1
# 417             76            1
#
# [418 rows x 15 columns]

# %%
final_data=data.drop(["Name","Ticket","Cabin","Embarked","Sex"],axis=1)

# %%
final_data
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare  \
# 0            892         0       3  34.50000      0      0    7.8292
# 1            893         1       3  47.00000      1      0    7.0000
# 2            894         0       2  62.00000      0      0    9.6875
# 3            895         0       3  27.00000      0      0    8.6625
# 4            896         1       3  22.00000      1      1   12.2875
# ..           ...       ...     ...       ...    ...    ...       ...
# 413         1305         0       3  30.27259      0      0    8.0500
# 414         1306         1       1  39.00000      0      0  108.9000
# 415         1307         0       3  38.50000      0      0    7.2500
# 416         1308         0       3  30.27259      0      0    8.0500
# 417         1309         0       3  30.27259      1      1   22.3583
#
#      Embarked_encoded  Cabin_Encoded  Sex_encoded
# 0                   1             76            1
# 1                   2             76            0
# 2                   1             76            1
# 3                   2             76            1
# 4                   2             76            0
# ..                ...            ...          ...
# 413                 2             76            1
# 414                 0             22            0
# 415                 2             76            1
# 416                 2             76            1
# 417                 0             76            1
#
# [418 rows x 10 columns]

# %%
final_data.corr()
# Out:
#                   PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId          1.000000 -0.023245 -0.026751 -0.030874  0.003818
# Survived            -0.023245  1.000000 -0.108615 -0.000011  0.099943
# Pclass              -0.026751 -0.108615  1.000000 -0.440782  0.001087
# Age                 -0.030874 -0.000011 -0.440782  1.000000 -0.079535
# SibSp                0.003818  0.099943  0.001087 -0.079535  1.000000
# Parch                0.043080  0.159120  0.018721 -0.045073  0.306895
# Fare                 0.008209  0.191382 -0.576619  0.326800  0.171488
# Embarked_encoded     0.040699 -0.076281  0.227983 -0.157996  0.052708
# Cabin_Encoded        0.012060 -0.127938  0.660165 -0.384965 -0.080243
# Sex_encoded          0.023245 -1.000000  0.108615  0.000011 -0.099943
#
#                      Parch      Fare  Embarked_encoded  Cabin_Encoded  \
# PassengerId       0.043080  0.008209          0.040699       0.012060
# Survived          0.159120  0.191382         -0.076281      -0.127938
# Pclass            0.018721 -0.576619          0.227983       0.660165
# Age              -0.045073  0.326800         -0.157996      -0.384965
# SibSp             0.306895  0.171488          0.052708      -0.080243
# Parch             1.000000  0.230001          0.054577      -0.045538
# Fare              0.230001  1.000000         -0.257031      -0.574351
# Embarked_encoded  0.054577 -0.257031          1.000000       0.273485
# Cabin_Encoded    -0.045538 -0.574351          0.273485       1.000000
# Sex_encoded      -0.159120 -0.191382          0.076281       0.127938
#
#                   Sex_encoded
# PassengerId          0.023245
# Survived            -1.000000
# Pclass               0.108615
# Age                  0.000011
# SibSp               -0.099943
# Parch               -0.159120
# Fare                -0.191382
# Embarked_encoded     0.076281
# Cabin_Encoded        0.127938
# Sex_encoded          1.000000

# %%
sns.heatmap(final_data.corr())
plt.show()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Embarked_encoded',
#        'Cabin_Encoded', 'Sex_encoded'],
#       dtype='object')

# %%
features=data.drop(["Survived","Embarked","Name","PassengerId","Sex","Parch","Ticket","Cabin"],axis=1)

# %%
features
# Out:
#      Pclass       Age  SibSp      Fare  Embarked_encoded  Cabin_Encoded  \
# 0         3  34.50000      0    7.8292                 1             76
# 1         3  47.00000      1    7.0000                 2             76
# 2         2  62.00000      0    9.6875                 1             76
# 3         3  27.00000      0    8.6625                 2             76
# 4         3  22.00000      1   12.2875                 2             76
# ..      ...       ...    ...       ...               ...            ...
# 413       3  30.27259      0    8.0500                 2             76
# 414       1  39.00000      0  108.9000                 0             22
# 415       3  38.50000      0    7.2500                 2             76
# 416       3  30.27259      0    8.0500                 2             76
# 417       3  30.27259      1   22.3583                 0             76
#
#      Sex_encoded
# 0              1
# 1              0
# 2              1
# 3              1
# 4              0
# ..           ...
# 413            1
# 414            0
# 415            1
# 416            1
# 417            1
#
# [418 rows x 7 columns]

# %%
target=pd.DataFrame(data["Survived"])

# %%
target
# Out:
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]

# %%
features.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked_encoded', 'Cabin_Encoded',
#        'Sex_encoded'],
#       dtype='object')

# %%
num_cols=["Pclass","Age","SibSp","Fare","Embarked_encoded","Cabin_Encoded"]

# %%
num_transfromer_dict={}
for col in num_cols:
    num_transfromer_dict[col]=StandardScaler().fit(data[[col]])

# %%
x_cols=num_cols
x_raw_feature=data[x_cols]

# %%
x_raw_feature
# Out:
#      Pclass       Age  SibSp      Fare  Embarked_encoded  Cabin_Encoded
# 0         3  34.50000      0    7.8292                 1             76
# 1         3  47.00000      1    7.0000                 2             76
# 2         2  62.00000      0    9.6875                 1             76
# 3         3  27.00000      0    8.6625                 2             76
# 4         3  22.00000      1   12.2875                 2             76
# ..      ...       ...    ...       ...               ...            ...
# 413       3  30.27259      0    8.0500                 2             76
# 414       1  39.00000      0  108.9000                 0             22
# 415       3  38.50000      0    7.2500                 2             76
# 416       3  30.27259      0    8.0500                 2             76
# 417       3  30.27259      1   22.3583                 0             76
#
# [418 rows x 6 columns]

# %%
for transforemer_name,transforemer in num_transfromer_dict.items():
    x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# Out:
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\1391451259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_raw_feature[f"{transforemer_name}_num_transformation"] = transforemer.transform(x_raw_feature[[transforemer_name]])

# %%
x_raw_feature
# Out:
#      Pclass       Age  SibSp      Fare  Embarked_encoded  Cabin_Encoded  \
# 0         3  34.50000      0    7.8292                 1             76
# 1         3  47.00000      1    7.0000                 2             76
# 2         2  62.00000      0    9.6875                 1             76
# 3         3  27.00000      0    8.6625                 2             76
# 4         3  22.00000      1   12.2875                 2             76
# ..      ...       ...    ...       ...               ...            ...
# 413       3  30.27259      0    8.0500                 2             76
# 414       1  39.00000      0  108.9000                 0             22
# 415       3  38.50000      0    7.2500                 2             76
# 416       3  30.27259      0    8.0500                 2             76
# 417       3  30.27259      1   22.3583                 0             76
#
#      Pclass_num_transformation  Age_num_transformation  \
# 0                     0.873482                0.334993
# 1                     0.873482                1.325530
# 2                    -0.315819                2.514175
# 3                     0.873482               -0.259330
# 4                     0.873482               -0.655545
# ..                         ...                     ...
# 413                   0.873482                0.000000
# 414                  -1.505120                0.691586
# 415                   0.873482                0.651965
# 416                   0.873482                0.000000
# 417                   0.873482                0.000000
#
#      SibSp_num_transformation  Fare_num_transformation  \
# 0                   -0.499470                -0.498407
# 1                    0.616992                -0.513274
# 2                   -0.499470                -0.465088
# 3                   -0.499470                -0.483466
# 4                    0.616992                -0.418471
# ..                        ...                      ...
# 413                 -0.499470                -0.494448
# 414                 -0.499470                 1.313753
# 415                 -0.499470                -0.508792
# 416                 -0.499470                -0.494448
# 417                  0.616992                -0.237906
#
#      Embarked_encoded_num_transformation  Cabin_Encoded_num_transformation
# 0                              -0.470915                          0.449022
# 1                               0.700767                          0.449022
# 2                              -0.470915                          0.449022
# 3                               0.700767                          0.449022
# 4                               0.700767                          0.449022
# ..                                   ...                               ...
# 413                             0.700767                          0.449022
# 414                            -1.642598                         -2.382865
# 415                             0.700767                          0.449022
# 416                             0.700767                          0.449022
# 417                            -1.642598                          0.449022
#
# [418 rows x 12 columns]

# %%
x= x_raw_feature[[col for col in x_raw_feature if col.endswith("_num_transformation")]]

# %%
x.head()
# Out:
#    Pclass_num_transformation  Age_num_transformation  \
# 0                   0.873482                0.334993
# 1                   0.873482                1.325530
# 2                  -0.315819                2.514175
# 3                   0.873482               -0.259330
# 4                   0.873482               -0.655545
#
#    SibSp_num_transformation  Fare_num_transformation  \
# 0                 -0.499470                -0.498407
# 1                  0.616992                -0.513274
# 2                 -0.499470                -0.465088
# 3                 -0.499470                -0.483466
# 4                  0.616992                -0.418471
#
#    Embarked_encoded_num_transformation  Cabin_Encoded_num_transformation
# 0                            -0.470915                          0.449022
# 1                             0.700767                          0.449022
# 2                            -0.470915                          0.449022
# 3                             0.700767                          0.449022
# 4                             0.700767                          0.449022

# %%
x =x.rename(columns={i:i.replace("_num_transformation","") for i in x.columns})

# %%
x
# Out:
#        Pclass       Age     SibSp      Fare  Embarked_encoded  Cabin_Encoded
# 0    0.873482  0.334993 -0.499470 -0.498407         -0.470915       0.449022
# 1    0.873482  1.325530  0.616992 -0.513274          0.700767       0.449022
# 2   -0.315819  2.514175 -0.499470 -0.465088         -0.470915       0.449022
# 3    0.873482 -0.259330 -0.499470 -0.483466          0.700767       0.449022
# 4    0.873482 -0.655545  0.616992 -0.418471          0.700767       0.449022
# ..        ...       ...       ...       ...               ...            ...
# 413  0.873482  0.000000 -0.499470 -0.494448          0.700767       0.449022
# 414 -1.505120  0.691586 -0.499470  1.313753         -1.642598      -2.382865
# 415  0.873482  0.651965 -0.499470 -0.508792          0.700767       0.449022
# 416  0.873482  0.000000 -0.499470 -0.494448          0.700767       0.449022
# 417  0.873482  0.000000  0.616992 -0.237906         -1.642598       0.449022
#
# [418 rows x 6 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,target,test_size=0.2,random_state=42,stratify=target)

# %%
logistics_model=LogisticRegression()

# %%
logistics_model.fit(x_train,y_train)
# Out:
# C:\Users\desai\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred_logistics=logistics_model.predict(x_train)

# %%
accuracy = accuracy_score(y_train,y_pred_logistics)*100
print('Accuracy of our model is equal ' + str(round(accuracy, 2)) + ' %.')
# Out:
# Accuracy of our model is equal 67.07 %.

# %%
random_model_classifier=RandomForestClassifier(n_estimators=100)

# %%
random_model_classifier.fit(x_train,y_train)
# Out:
# C:\Users\desai\AppData\Local\Temp\ipykernel_16748\3065128866.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_model_classifier.fit(x_train,y_train)
# RandomForestClassifier()

# %%
y_pred_random=random_model_classifier.predict(x_train)

# %%
accuracy = accuracy_score(y_train,y_pred_random)*100
print('Accuracy of our model is equal ' + str(round(accuracy, 2)) + ' %.')
# Out:
# Accuracy of our model is equal 97.01 %.

# %%
user_inputs = []
for column in x.columns:
    user_inputs.append(input(f"{column} : "))
# Out:
# Pclass :  1
# Age :  35
# SibSp :  0
# Fare :  478
# Embarked_encoded :  52
# Cabin_Encoded :  41

# %%
user_clean_input = [float(i) for i in user_inputs]

# %%
random_model_classifier.predict([user_clean_input])
# Out:
# C:\Users\desai\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
